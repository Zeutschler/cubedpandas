# %% [markdown]
# ## CubedPandas - Sample Notebook
# This notebook demonstrates the use of CubedPandas to analyze a sample dataset.

# %%
import pandas as pd
from cubedpandas import cubed

# Load the sample dataset
cdf = cubed(pd.read_csv('web_app/data.csv'))
cdf
# Out:
# 'Cube(1000 records, 9 dimensions, 8 measures)'
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
cdf.Quantity_ >= 10
# Out:
# 1190

# %%
cdf.Quantity.City.Yangon.Payment.Ewallet
# Out:
# 707

# %%
cdf.Customer_type.Normal.Member[cdf.Unit_price_ > 90]
# Out:
# 12165.339999999998

# %%
cdf.Customer_type["Normal", "Member"]
# Out:
# 55672.130000000005

# %%
cdf.slice((cdf.Product_line, cdf.Gender, cdf.City))
# Out:
#                                             Rating      Tax 5%        Total  \
# Product line
# (all)                  (, )                 6972.7  15379.3690  322966.7490
#                        subtotal             6972.7  15379.3690  322966.7490
# Electronic accessories (Female, Mandalay)    198.9    388.8815    8166.5115
#                        (Female, Naypyitaw)   194.6    427.1055    8969.2155
#                        (Female, Yangon)      176.6    474.5855    9966.2955
#                        (Male, Mandalay)      192.5    423.0920    8884.9320
#                        (Male, Naypyitaw)     176.5    476.1790    9999.7590
#                        (Male, Yangon)        238.1    397.6580    8350.8180
#                        subtotal             1177.2   2587.5015   54337.5315
# Fashion accessories    (Female, Mandalay)    220.5    432.4520    9081.4920
#                        (Female, Naypyitaw)   266.4    548.5565   11519.6865
# ...
